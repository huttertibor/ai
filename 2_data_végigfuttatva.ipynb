# %% [markdown]
# <a href="https://colab.research.google.com/github/huttertibor/ai/blob/main/2_data_v%C3%A9gigfuttatva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Exploration with Pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!find . -name titanic.csv -print

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(12345)
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %%
/content/drive/MyDrive/Datasets/titanic/titanic.csv

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Lname        156 non-null    object
#  4   Name         156 non-null    object
#  5   Sex          156 non-null    object
#  6   Age          126 non-null    float64
#  7   SibSp        156 non-null    int64
#  8   Parch        156 non-null    int64
#  9   Ticket       156 non-null    object
#  10  Fare         156 non-null    float64
#  11  Cabin        31 non-null     object
#  12  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 16.0+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %% [markdown]
# ### Indexing

# %%
print(f"type(df.iloc[3])={type(df.iloc[3])}")
df.iloc[3]
# Out:
# type(df.iloc[3])=<class 'pandas.core.series.Series'>
# PassengerId                                      4
# Survived                                         1
# Pclass                                           1
# Lname                                     Futrelle
# Name            Mrs. Jacques Heath (Lily May Peel)
# Sex                                         female
# Age                                           35.0
# SibSp                                            1
# Parch                                            0
# Ticket                                      113803
# Fare                                          53.1
# Cabin                                         C123
# Embarked                                         S
# Name: 3, dtype: object

# %%
print(f"df.loc[0:4,'Ticket']={type(df.loc[0:4,'Ticket'])}")
df.loc[0:4,'Ticket']
# Out:
# df.loc[0:4,'Ticket']=<class 'pandas.core.series.Series'>
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %%
print(f"df.loc[0:4,'Ticket']={type(df.loc[0:4,['Ticket','Pclass']])}")
df.loc[0:4,['Ticket','Pclass']]
# Out:
# df.loc[0:4,'Ticket']=<class 'pandas.core.frame.DataFrame'>
#              Ticket  Pclass
# 0         A/5 21171       3
# 1          PC 17599       1
# 2  STON/O2. 3101282       3
# 3            113803       1
# 4            373450       3

# %%
print(f"type(df['Ticket'])={type(df['Ticket'])}")
df['Ticket'].head()
# Out:
# type(df['Ticket'])=<class 'pandas.core.series.Series'>
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %%
df[['Embarked', 'Ticket']].head()
# Out:
#   Embarked            Ticket
# 0        S         A/5 21171
# 1        C          PC 17599
# 2        S  STON/O2. 3101282
# 3        S            113803
# 4        S            373450

# %% [markdown]
# ### Selections

# %%
print(f"type(df[df['Age'] > 70])= {type(df[df['Age'] > 70])}")
df[df['Age'] > 70]
# Out:
# type(df[df['Age'] > 70])= <class 'pandas.core.frame.DataFrame'>
#      PassengerId  Survived  Pclass        Lname           Name   Sex   Age  \
# 96            97         0       1  Goldschmidt   Mr. George B  male  71.0
# 116          117         0       3      Connors    Mr. Patrick  male  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 96       0      0  PC 17754  34.6542    A5        C
# 116      0      0    370369   7.7500   NaN        Q

# %%
print(f"type(df['Age'] > 70)={type(df['Age'] > 70)}  (df['Age'] > 70).shape={(df['Age'] > 70).shape}")
df['Age'] > 70
# Out:
# type(df['Age'] > 70)=<class 'pandas.core.series.Series'>  (df['Age'] > 70).shape=(156,)
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
print(f'type(df.query("Age > 70")={type(df.query("Age > 70"))}')
df.query("Age > 70")
# Out:
# type(df.query("Age > 70")=<class 'pandas.core.frame.DataFrame'>
#      PassengerId  Survived  Pclass        Lname           Name   Sex   Age  \
# 96            97         0       1  Goldschmidt   Mr. George B  male  71.0
# 116          117         0       3      Connors    Mr. Patrick  male  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 96       0      0  PC 17754  34.6542    A5        C
# 116      0      0    370369   7.7500   NaN        Q

# %%
print(f"df[(df['Age'] == 11) & (df['SibSp'] == 5)] = {type(df[(df['Age'] == 11) & (df['SibSp'] == 5)])}")
df[(df['Age'] == 11) & (df['SibSp'] == 5)]
# Out:
# df[(df['Age'] == 11) & (df['SibSp'] == 5)] = <class 'pandas.core.frame.DataFrame'>
#     PassengerId  Survived  Pclass    Lname                        Name   Sex  \
# 59           60         0       3  Goodwin   Master. William Frederick  male
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59  11.0      5      2  CA 2144  46.9   NaN        S

# %%
df[(df.Age == 11) | (df.SibSp == 5)]

# %%
df.query('(Age == 11) | (SibSp == 5)')

# %% [markdown]
# ### Unique Values

# %%
df['Embarked'].unique()

# %% [markdown]
# ### Sorting

# %%
df.sort_values('Age', ascending = False).head()
# Out:
#      PassengerId  Survived  Pclass        Lname                      Name  \
# 96            97         0       1  Goldschmidt              Mr. George B
# 116          117         0       3      Connors               Mr. Patrick
# 33            34         0       2      Wheadon              Mr. Edward H
# 54            55         0       1        Ostby   Mr. Engelhart Cornelius
# 94            95         0       3        Coxon                Mr. Daniel
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 54   male  65.0      0      1      113509  61.9792   B30        C
# 94   male  59.0      0      0      364500   7.2500   NaN        S

# %% [markdown]
# ### Aggregations

# %%
df.shape
# Out:
# (156, 13)

# %%
print(f"type(df['Survived'].value_counts())={type(df['Survived'].value_counts())}")
df['Survived'].value_counts()
# Out:
# type(df['Survived'].value_counts())=<class 'pandas.core.series.Series'>
# Survived
# 0    102
# 1     54
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    96
# 1    30
# 2    30
# Name: count, dtype: int64

# %%
res = df.groupby('Pclass')['Survived'].value_counts()
res_type = type(res)
print(f"type(df.groupby(['Pclass', 'Survived'])['PassengerId'].count())={res_type}")

df.groupby(['Pclass', 'Survived'])['PassengerId'].count()
# Out:
# type(df.groupby(['Pclass', 'Survived'])['PassengerId'].count())=<class 'pandas.core.series.Series'>
# Pclass  Survived
# 1       0           18
#         1           12
# 2       0           16
#         1           14
# 3       0           68
#         1           28
# Name: PassengerId, dtype: int64

# %%
min(df['Age'])
# Out:
# 0.83

# %%
df['Age'].min()
# Out:
# 0.83

# %%
df['Age'].max()
# Out:
# 71.0

# %%
df['Age'].mean()
# Out:
# 28.141507936507935

# %%
df['Age'].median()
# Out:
# 26.0

# %%
mean_age_by_survived = df.groupby('Survived')['Age'].mean()
mean_age_by_survived
# Out:
# Survived
# 0    29.358824
# 1    25.617805
# Name: Age, dtype: float64

# %%
std_age_by_survived = df.groupby('Survived')['Age'].std()
std_age_by_survived
# Out:
# Survived
# 0    15.443370
# 1    12.524765
# Name: Age, dtype: float64

# %% [markdown]
# ### Merge

# %%
df1 = mean_age_by_survived.round(0).reset_index()
df2 = std_age_by_survived.round(0).reset_index()

# %%
df1
# Out:
#    Survived   Age
# 0         0  29.0
# 1         1  26.0

# %%
df2
# Out:
#    Survived   Age
# 0         0  15.0
# 1         1  13.0

# %%
df3 = pd.merge(df1, df2, on='Survived')

# %%
df3
# Out:
#    Survived  Age_x  Age_y
# 0         0   29.0   15.0
# 1         1   26.0   13.0

# %%
df3.columns = ['Survived', 'Average Age', 'Age Standard Deviation']

# %%
df3
# Out:
#    Survived  Average Age  Age Standard Deviation
# 0         0         29.0                    15.0
# 1         1         26.0                    13.0

# %% [markdown]
# ### Pivot Tables

# %%
pt =df.pivot_table(index='Pclass',
               columns='Survived',
               values='PassengerId',
               aggfunc='count')
pt
# Out:
# Survived   0   1
# Pclass
# 1         18  12
# 2         16  14
# 3         68  28

# %%
pt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 1 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      int64
#  1   1       3 non-null      int64
# dtypes: int64(2)
# memory usage: 72.0 bytes

# %% [markdown]
# ### Correlations

# %%
df['IsFemale'] = df['Sex'] == 'female'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Lname        156 non-null    object
#  4   Name         156 non-null    object
#  5   Sex          156 non-null    object
#  6   Age          126 non-null    float64
#  7   SibSp        156 non-null    int64
#  8   Parch        156 non-null    int64
#  9   Ticket       156 non-null    object
#  10  Fare         156 non-null    float64
#  11  Cabin        31 non-null     object
#  12  Embarked     155 non-null    object
#  13  IsFemale     156 non-null    bool
# dtypes: bool(1), float64(2), int64(5), object(6)
# memory usage: 16.1+ KB

# %%
selected_columns = ['Age', 'Fare', 'Pclass', 'Survived','SibSp','Parch','Fare']  # Choose your columns
correlation_matrix = df[selected_columns].corr()
print(correlation_matrix)
# Out:
#                Age      Fare    Pclass  Survived     SibSp     Parch      Fare
# Age       1.000000  0.024494 -0.362627 -0.120416 -0.393500 -0.215169  0.024494
# Fare      0.024494  1.000000 -0.607256  0.029343  0.271997  0.254822  1.000000
# Pclass   -0.362627 -0.607256  1.000000 -0.116340  0.087420  0.016491 -0.607256
# Survived -0.120416  0.029343 -0.116340  1.000000 -0.066943  0.039435  0.029343
# SibSp    -0.393500  0.271997  0.087420 -0.066943  1.000000  0.399040  0.271997
# Parch    -0.215169  0.254822  0.016491  0.039435  0.399040  1.000000  0.254822
# Fare      0.024494  1.000000 -0.607256  0.029343  0.271997  0.254822  1.000000

# %%
correlated_with_survived = df[selected_columns].corr()['Survived'].sort_values()
correlated_with_survived
# Out:
# Age        -0.120416
# Pclass     -0.116340
# SibSp      -0.066943
# Fare        0.029343
# Fare        0.029343
# Parch       0.039435
# Survived    1.000000
# Name: Survived, dtype: float64

# %%
correlated_with_survived.iloc[:-1].plot(kind='bar',
                                        title='Titanic Passengers: correlation with survival');

# %% [markdown]
# # Visual Data Exploration with Matplotlib

# %%
data1 = np.random.normal(0, 0.1, 1000)
data2 = np.random.normal(1, 0.4, 1000) + np.linspace(0, 1, 1000)
data3 = 2 + np.random.random(1000) * np.linspace(1, 5, 1000)
data4 = np.random.normal(3, 0.2, 1000) + 0.3 * np.sin(np.linspace(0, 20, 1000))

# %%
data = np.vstack([data1, data2, data3, data4]).transpose()

# %%
df = pd.DataFrame(data, columns=['data1', 'data2', 'data3', 'data4'])
df.head()

# %% [markdown]
# ### Line Plot

# %%
df.plot(title='Line plot');

# %%
plt.plot(df[selected_columns])
plt.title('Line plot')
plt.legend(['data1', 'data2', 'data3', 'data4']);

# %% [markdown]
# ### Scatter Plot

# %%
df.plot(style='.');

# %%
_ = df[selected_columns.plot(kind='scatter', x='data1', y='data2',
            xlim=(-1.5, 1.5), ylim=(0, 3))
# Out:
#   File "<ipython-input-79-de2ceb9af38e>", line 2
#     xlim=(-1.5, 1.5), ylim=(0, 3))
#                                   ^
# SyntaxError: incomplete input

# %% [markdown]
# ### Histograms

# %%
df.plot(kind='hist',
        bins=50,
        title='Histogram',
        alpha=0.6);

# %% [markdown]
# ### Cumulative distribution

# %%
df.plot(kind='hist',
        bins=100,
        title='Cumulative distributions',
        density=True,
        cumulative=True,
        alpha=0.4);

# %% [markdown]
# ### Box Plot

# %%
df.plot(kind='box',
        title='Boxplot');

# %% [markdown]
# ### Subplots

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))

df.plot(ax=ax[0][0],
        title='Line plot')

df.plot(ax=ax[0][1],
        style='o',
        title='Scatter plot')

df.plot(ax=ax[1][0],
        kind='hist',
        bins=50,
        title='Histogram')

df.plot(ax=ax[1][1],
        kind='box',
        title='Boxplot')

plt.tight_layout()

# %% [markdown]
# ### Pie charts

# %%
gt01 = df['data1'] > 0.1
piecounts = gt01.value_counts()
piecounts

# %%
piecounts.plot(kind='pie',
               figsize=(5, 5),
               explode=[0, 0.15],
               labels=['<= 0.1', '> 0.1'],
               autopct='%1.1f%%',
               shadow=True,
               startangle=90,
               fontsize=16);

# %% [markdown]
# ### Hexbin plot

# %%
data = np.vstack([np.random.normal((0, 0), 2, size=(1000, 2)),
                  np.random.normal((9, 9), 3, size=(2000, 2))])
df = pd.DataFrame(data, columns=['x', 'y'])

# %%
df.head()

# %%
df.plot();

# %%
df.plot(kind='kde');

# %%
df.plot(kind='hexbin', x='x', y='y', bins=100, cmap='rainbow');

# %% [markdown]
# # Unstructured data

# %% [markdown]
# ### Images

# %%
from PIL import Image

# %%
img = Image.open('../data/iss.jpg')
img

# %%
type(img)

# %%
imgarray = np.asarray(img)

# %%
type(imgarray)

# %%
imgarray.shape

# %%
imgarray.ravel().shape

# %%
435 * 640 * 3

# %% [markdown]
# ### Sound

# %%
from scipy.io import wavfile

# %%
rate, snd = wavfile.read(filename='../data/sms.wav')

# %%
from IPython.display import Audio

# %%
Audio(data=snd, rate=rate)

# %%
len(snd)

# %%
snd

# %%
plt.plot(snd)

# %%
_ = plt.specgram(snd, NFFT=1024, Fs=44100)
plt.ylabel('Frequency (Hz)')
plt.xlabel('Time (s)')

# %% [markdown]
# # Data Exploration Exercises

# %% [markdown]
# ## Exercise 1
# - load the dataset: `../data/international-airline-passengers.csv`
# - inspect it using the `.info()` and `.head()` commands
# - use the function [`pd.to_datetime()`](http://pandas.pydata.org/pandas-docs/version/0.20/generated/pandas.to_datetime.html) to change the column type of 'Month' to a datatime type
# - set the index of df to be a datetime index using the column 'Month' and the `df.set_index()` method
# - choose the appropriate plot and display the data
# - choose appropriate scale
# - label the axes

# %% [markdown]
# ## Exercise 2
# - load the dataset: `../data/weight-height.csv`
# - inspect it
# - plot it using a scatter plot with Weight as a function of Height
# - plot the male and female populations with 2 different colors on a new scatter plot
# - remember to label the axes

# %% [markdown]
# ## Exercise 3
# - plot the histogram of the heights for males and for females on the same plot
# - use alpha to control transparency in the plot comand
# - plot a vertical line at the mean of each population using `plt.axvline()`

# %% [markdown]
# ## Exercise 4
# - plot the weights of the males and females using a box plot
# - which one is easier to read?
# - (remember to put in titles, axes and legends)

# %% [markdown]
# ## Exercise 5
# - load the dataset: `../data/titanic-train.csv`
# - learn about scattermatrix here: http://pandas.pydata.org/pandas-docs/stable/visualization.html
# - display the data using a scattermatrix
